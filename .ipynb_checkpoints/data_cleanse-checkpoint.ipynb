# %%
import pandas as pd
import os

# %%
company_info = pd.read_csv('company_info.csv')

# %%
company_info.head()
# Out:
#    Unnamed: 0 symbol quarter  year                                 label  \
# 0           0    BDX      Q3  2017  Liabilities and Shareholders’ Equity
# 1           1    BDX      Q3  2017  Liabilities and Shareholders’ Equity
# 2           2    BDX      Q3  2017  Liabilities and Shareholders’ Equity
# 3           3    BDX      Q3  2017  Liabilities and Shareholders’ Equity
# 4           4    BDX      Q3  2017  Liabilities and Shareholders’ Equity
#
#                             concept unit         value
# 0  LiabilitiesAndStockholdersEquity  usd  3.716600e+10
# 1  LiabilitiesAndStockholdersEquity  usd  3.716600e+10
# 2  LiabilitiesAndStockholdersEquity  usd  3.716600e+10
# 3  LiabilitiesAndStockholdersEquity  usd  3.716600e+10
# 4  LiabilitiesAndStockholdersEquity  usd  3.716600e+10

# %%
company_info.rename(columns={'Unnamed: 0': 'index',
                   'label': 'entry_label',
                    'concept': 'entry_concept',
                    'unit': 'entry_unit',
                    'value': 'entry_value'
                   }, inplace=True)

# %%
company_info.head()
# Out:
#    index symbol quarter  year                           entry_label  \
# 0      0    BDX      Q3  2017  Liabilities and Shareholders’ Equity
# 1      1    BDX      Q3  2017  Liabilities and Shareholders’ Equity
# 2      2    BDX      Q3  2017  Liabilities and Shareholders’ Equity
# 3      3    BDX      Q3  2017  Liabilities and Shareholders’ Equity
# 4      4    BDX      Q3  2017  Liabilities and Shareholders’ Equity
#
#                       entry_concept entry_unit   entry_value
# 0  LiabilitiesAndStockholdersEquity        usd  3.716600e+10
# 1  LiabilitiesAndStockholdersEquity        usd  3.716600e+10
# 2  LiabilitiesAndStockholdersEquity        usd  3.716600e+10
# 3  LiabilitiesAndStockholdersEquity        usd  3.716600e+10
# 4  LiabilitiesAndStockholdersEquity        usd  3.716600e+10

# %%
company_info_cleaned = company_info.fillna("'Liabilities and Shareholders' Equity'")

# %%
company_info_cleaned.head()
# Out:
#    index symbol quarter  year                           entry_label  \
# 0      0    BDX      Q3  2017  Liabilities and Shareholders’ Equity
# 1      1    BDX      Q3  2017  Liabilities and Shareholders’ Equity
# 2      2    BDX      Q3  2017  Liabilities and Shareholders’ Equity
# 3      3    BDX      Q3  2017  Liabilities and Shareholders’ Equity
# 4      4    BDX      Q3  2017  Liabilities and Shareholders’ Equity
#
#                       entry_concept entry_unit   entry_value
# 0  LiabilitiesAndStockholdersEquity        usd  3.716600e+10
# 1  LiabilitiesAndStockholdersEquity        usd  3.716600e+10
# 2  LiabilitiesAndStockholdersEquity        usd  3.716600e+10
# 3  LiabilitiesAndStockholdersEquity        usd  3.716600e+10
# 4  LiabilitiesAndStockholdersEquity        usd  3.716600e+10

# %%
company_info_cleaned.to_csv('company_info.csv', encoding='utf-8', index=True)
